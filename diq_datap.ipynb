# %% [markdown]
# YDATA PROFILING

# %%
from ydata_profiling import ProfileReport
import pandas as pd

# %%
# Load the dataset
db = pd.read_csv('Comune-di-Milano-Esercizi-di-vicinato-in-sede-fissa.csv',sep=';',encoding='unicode_escape')

# %%
# Generate the profiling report
PROFILE = ProfileReport(db, title="Profiling Report").to_file("db_REPORT_profiling.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 13/13 [00:01<00:00, 11.64it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
